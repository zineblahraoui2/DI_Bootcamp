# %% [markdown]
# Company’s financial reports stored in an Excel file are considered structured data.
# Photographs uploaded to a social media platform are considered unstructured data.
# A collection of news articles on a website is unstructured data.
# Inventory data stored in a relational database is structured data.
# Recorded interviews from a market research study are unstructured data.
